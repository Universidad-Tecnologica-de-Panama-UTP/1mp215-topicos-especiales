# %% [markdown]
# # 1. Clasificación de dígitos MNIST con Gaussian Naive Bayes
#
# Este notebook muestra cómo entrenar y evaluar un clasificador GNB sobre el dataset MNIST usando bibliotecas de Python.

# %% [markdown]
# ## 2. Importar bibliotecas necesarias
#
# Importamos pandas, numpy, time y el clasificador Gaussian Naive Bayes de scikit-learn.

# %%
# Importar bibliotecas necesarias
import pandas as pd
import numpy as np
import time
from sklearn.naive_bayes import GaussianNB

# %% [markdown]
# ## 3. Definir parámetros globales
#
# Establecemos el número de muestras para entrenamiento y prueba.

# %%
# Definir parámetros globales
muestras_entrenamiento = 50000  # Número de muestras de entrenamiento
muestras_prueba = 10000         # Número de muestras de prueba

# %% [markdown]
# ## 4. Inicializar variables para medir tiempos
#
# Estas variables nos permitirán medir el tiempo de entrenamiento y prueba.

# %%
# Inicializar variables para medir tiempos
inicio_tiempo_entrenamiento = 0
fin_tiempo_entrenamiento = 0
tiempo_entrenamiento = 0

inicio_tiempo_prueba = 0
fin_tiempo_prueba = 0
tiempo_prueba = 0

# %% [markdown]
# ## 5. Función para cargar el dataset
#
# Esta función lee un archivo CSV y devuelve los datos normalizados y las etiquetas.

# %%
def cargar_dataset(nombre_archivo, muestras):
    """
    Carga un dataset CSV y devuelve los datos normalizados y las etiquetas.
    """
    x = []  # Datos de entrada
    y = []  # Etiquetas
    datos = pd.read_csv(nombre_archivo)
    y = np.array(datos.iloc[0:muestras, 0])  # Primera columna: etiquetas
    x = np.array(datos.iloc[0:muestras, 1:]) / 255  # Normalización
    return x, y

# %% [markdown]
# ## 6. Cargar los datos de entrenamiento y prueba
#
# Usamos la función definida para cargar los datos.

# %%
# Cargar los datos de entrenamiento y prueba
x_entrenamiento, y_entrenamiento = cargar_dataset("../../datasets/mnist/mnist_train.csv", muestras_entrenamiento)
x_prueba, y_prueba = cargar_dataset("../../datasets/mnist/mnist_test.csv", muestras_prueba)

# %% [markdown]
# ## 7. Crear y entrenar el modelo GNB
#
# Entrenamos el modelo y medimos el tiempo de entrenamiento.

# %%
# Crear y entrenar el modelo GNB
gnb = GaussianNB()
inicio_tiempo_entrenamiento = time.time()
gnb.fit(x_entrenamiento, y_entrenamiento)
fin_tiempo_entrenamiento = time.time()
tiempo_entrenamiento = fin_tiempo_entrenamiento - inicio_tiempo_entrenamiento
print(f"Tiempo de entrenamiento: {tiempo_entrenamiento:.2f} s")
# Out:
# Tiempo de entrenamiento: 0.88 s

# %% [markdown]
# ## 8. Evaluación global rápida del modelo
#
# Calculamos la precisión del modelo sobre todo el conjunto de prueba de una sola vez usando `gnb.score` y medimos el tiempo de inferencia total.

# %%
# Evaluación simple sobre todo el conjunto de prueba y cálculo del tiempo de inferencia
import time
inicio_inferencia = time.time()
precision = gnb.score(x_prueba, y_prueba)
fin_inferencia = time.time()
tiempo_inferencia = fin_inferencia - inicio_inferencia
print(f"Precisión global (score): {precision:.4f}")
print(f"Tiempo de inferencia sobre todo el conjunto de prueba: {tiempo_inferencia:.4f} s")
# Out:
# Precisión global (score): 0.5544
# Tiempo de inferencia sobre todo el conjunto de prueba: 0.5514 s

# %% [markdown]
# ## 9. Evaluar el modelo sobre el dataset de prueba
#
# Calculamos la precisión y mostramos resultados para cada muestra.

# %%
# Evaluar el modelo sobre el dataset de prueba
resultados_validos = 0
inicio_tiempo_prueba = time.time()
for i in range(len(y_prueba)):
    resultado_esperado = int(y_prueba[int(i)])
    resultado_obtenido =  gnb.predict(x_prueba[int(i)].reshape(1, -1)).item()
    resultado_texto = "Falló"
    if resultado_obtenido == resultado_esperado:
        resultados_validos += 1
        resultado_texto = " OK "
    # Imprimir solo los primeros 20 resultados
    print("Nº ", i + 1, " | Resultado esperado: ", resultado_esperado, " | Resultado obtenido: ", resultado_obtenido, " | ", resultado_texto,
              " | Precisión: ", round((resultados_validos / (i + 1)) * 100, 2), "%")
fin_tiempo_prueba = time.time()
tiempo_prueba = fin_tiempo_prueba - inicio_tiempo_prueba
# Out:
# Nº  1  | Resultado esperado:  7  | Resultado obtenido:  9  |  Falló  | Precisión:  0.0 %
# Nº  2  | Resultado esperado:  2  | Resultado obtenido:  2  |   OK   | Precisión:  50.0 %
# Nº  3  | Resultado esperado:  1  | Resultado obtenido:  1  |   OK   | Precisión:  66.67 %
# Nº  4  | Resultado esperado:  0  | Resultado obtenido:  0  |   OK   | Precisión:  75.0 %
# Nº  5  | Resultado esperado:  4  | Resultado obtenido:  9  |  Falló  | Precisión:  60.0 %
# Nº  6  | Resultado esperado:  1  | Resultado obtenido:  1  |   OK   | Precisión:  66.67 %
# Nº  7  | Resultado esperado:  4  | Resultado obtenido:  8  |  Falló  | Precisión:  57.14 %
# Nº  8  | Resultado esperado:  9  | Resultado obtenido:  9  |   OK   | Precisión:  62.5 %
# Nº  9  | Resultado esperado:  5  | Resultado obtenido:  4  |  Falló  | Precisión:  55.56 %
# Nº  10  | Resultado esperado:  9  | Resultado obtenido:  9  |   OK   | Precisión:  60.0 %
# Nº  11  | Resultado esperado:  0  | Resultado obtenido:  0  |   OK   | Precisión:  63.64 %
# Nº  12  | Resultado esperado:  6  | Resultado obtenido:  6  |   OK   | Precisión:  66.67 %
# Nº  13  | Resultado esperado:  9  | Resultado obtenido:  9  |   OK   | Precisión:  69.23 %
# Nº  14  | Resultado esperado:  0  | Resultado obtenido:  0  |   OK   | Precisión:  71.43 %
# Nº  15  | Resultado esperado:  1  | Resultado obtenido:  1  |   OK   | Precisión:  73.33 %
# Nº  16  | Resultado esperado:  5  | Resultado obtenido:  0  |  Falló  | Precisión:  68.75 %
# Nº  17  | Resultado esperado:  9  | Resultado obtenido:  9  |   OK   | Precisión:  70.59 %
# Nº  18  | Resultado esperado:  7  | Resultado obtenido:  7  |   OK   | Precisión:  72.22 %
# Nº  19  | Resultado esperado:  3  | Resultado obtenido:  2  |  Falló  | Precisión:  68.42 %
# Nº  20  | Resultado esperado:  4  | Resultado obtenido:  9  |  Falló  | Precisión:  65.0 %
# Nº  21  | Resultado esperado:  9  | Resultado obtenido:  9  |   OK   | Precisión:  66.67 %
# Nº  22  | Resultado esperado:  6  | Resultado obtenido:  6  |   OK   | Precisión:  68.18 %
# Nº  23  | Resultado esperado:  6  | Resultado obtenido:  6  |   OK   | Precisión:  69.57 %
# Nº  24  | Resultado esperado:  5  | Resultado obtenido:  8  |  Falló  | Precisión:  66.67 %
# Nº  25  | Resultado esperado:  4  | Resultado obtenido:  9  |  Falló  | Precisión:  64.0 %
# Nº  26  | Resultado esperado:  0  | Resultado obtenido:  0  |   OK   | Precisión:  65.38 %
# Nº  27  | Resultado esperado:  7  | Resultado obtenido:  7  |   OK   | Precisión:  66.67 %
# Nº  28  | Resultado esperado:  4  | Resultado obtenido:  9  |  Falló  | Precisión:  64.29 %
# Nº  29  | Resultado esperado:  0  | Resultado obtenido:  0  |   OK   | Precisión:  65.52 %
# Nº  30  | Resultado esperado:  1  | Resultado obtenido:  1  |   OK   | Precisión:  66.67 %
# Nº  31  | Resultado esperado:  3  | Resultado obtenido:  9  |  Falló  | Precisión:  64.52 %
# Nº  32  | Resultado esperado:  1  | Resultado obtenido:  1  |   OK   | Precisión:  65.62 %
# Nº  33  | Resultado esperado:  3  | Resultado obtenido:  8  |  Falló  | Precisión:  63.64 %
# Nº  34  | Resultado esperado:  4  | Resultado obtenido:  0  |  Falló  | Precisión:  61.76 %
# Nº  35  | Resultado esperado:  7  | Resultado obtenido:  8  |  Falló  | Precisión:  60.0 %
# Nº  36  | Resultado esperado:  2  | Resultado obtenido:  8  |  Falló  | Precisión:  58.33 %
# Nº  37  | Resultado esperado:  7  | Resultado obtenido:  7  |   OK   | Precisión:  59.46 %
# Nº  38  | Resultado esperado:  1  | Resultado obtenido:  1  |   OK   | Precisión:  60.53 %
# Nº  39  | Resultado esperado:  2  | Resultado obtenido:  8  |  Falló  | Precisión:  58.97 %
# Nº  40  | Resultado esperado:  1  | Resultado obtenido:  1  |   OK   | Precisión:  60.0 %
# Nº  41  | Resultado esperado:  1  | Resultado obtenido:  1  |   OK   | Precisión:  60.98 %
# Nº  42  | Resultado esperado:  7  | Resultado obtenido:  9  |  Falló  | Precisión:  59.52 %
# Nº  43  | Resultado esperado:  4  | Resultado obtenido:  9  |  Falló  | Precisión:  58.14 %
# Nº  44  | Resultado esperado:  2  | Resultado obtenido:  6  |  Falló  | Precisión:  56.82 %
# Nº  45  | Resultado esperado:  3  | Resultado obtenido:  8  |  Falló  | Precisión:  55.56 %
# Nº  46  | Resultado esperado:  5  | Resultado obtenido:  8  |  Falló  | Precisión:  54.35 %
# Nº  47  | Resultado esperado:  1  | Resultado obtenido:  8  |  Falló  | Precisión:  53.19 %
# Nº  48  | Resultado esperado:  2  | Resultado obtenido:  6  |  Falló  | Precisión:  52.08 %
# Nº  49  | Resultado esperado:  4  | Resultado obtenido:  9  |  Falló  | Precisión:  51.02 %
# Nº  50  | Resultado esperado:  4  | Resultado obtenido:  8  |  Falló  | Precisión:  50.0 %
# Nº  51  | Resultado esperado:  6  | Resultado obtenido:  6  |   OK   | Precisión:  50.98 %
# Nº  52  | Resultado esperado:  3  | Resultado obtenido:  3  |   OK   | Precisión:  51.92 %
# Nº  53  | Resultado esperado:  5  | Resultado obtenido:  8  |  Falló  | Precisión:  50.94 %
# Nº  54  | Resultado esperado:  5  | Resultado obtenido:  8  |  Falló  | Precisión:  50.0 %
# Nº  55  | Resultado esperado:  6  | Resultado obtenido:  6  |   OK   | Precisión:  50.91 %
# Nº  56  | Resultado esperado:  0  | Resultado obtenido:  8  |  Falló  | Precisión:  50.0 %
# Nº  57  | Resultado esperado:  4  | Resultado obtenido:  8  |  Falló  | Precisión:  49.12 %
# Nº  58  | Resultado esperado:  1  | Resultado obtenido:  1  |   OK   | Precisión:  50.0 %
# Nº  59  | Resultado esperado:  9  | Resultado obtenido:  9  |   OK   | Precisión:  50.85 %
# Nº  60  | Resultado esperado:  5  | Resultado obtenido:  8  |  Falló  | Precisión:
| Resultado esperado:  9  | Resultado obtenido:  9  |   OK   | Precisión:  52.19 %
# Nº  503  | Resultado esperado:  5  | Resultado obtenido:  3  |  Falló  | Precisión:  52.09 %
# Nº  504  | Resultado esperado:  2  | Resultado obtenido:  2  |   OK   | Precisión:  52.18 %
# Nº  505  | Resultado esperado:  1  | Resultado obtenido:  1  |   OK   | Precisión:  52.28 %
# Nº  506  | Resultado esperado:  3  | Resultado obtenido:  8  |  Falló  | Precisión:  52.17 %
# Nº  507  | Resultado esperado:  1  | Resultado obtenido:  1  |   OK   | Precisión:  52.27 %
# Nº  508  | Resultado esperado:  3  | Resultado obtenido:  8  |  Falló  | Precisión:  52.17 %
# Nº  509  | Resultado esperado:  6  | Resultado obtenido:  8  |  Falló  | Precisión:  52.06 %
# Nº  510  | Resultado esperado:  5  | Resultado obtenido:  8  |  Falló  | Precisión:  51.96 %
# Nº  511  | Resultado esperado:  7  | Resultado obtenido:  9  |  Falló  | Precisión:  51.86 %
# Nº  512  | Resultado esperado:  4  | Resultado obtenido:  9  |  Falló  | Precisión:  51.76 %
# Nº  513  | Resultado esperado:  2  | Resultado obtenido:  6  |  Falló  | Precisión:  51.66 %
# Nº  514  | Resultado esperado:  2  | Resultado obtenido:  2  |   OK   | Precisión:  51.75 %
# Nº  515  | Resultado esperado:  6  | Resultado obtenido:  6  |   OK   | Precisión:  51.84 %
# Nº  516  | Resultado esperado:  3  | Resultado obtenido:  1  |  Falló  | Precisión:  51.74 %
# Nº  517  | Resultado esperado:  2  | Resultado obtenido:  6  |  Falló  | Precisión:  51.64 %
# Nº  518  | Resultado esperado:  6  | Resultado obtenido:  6  |   OK   | Precisión:  51.74 %
# Nº  519  | Resultado esperado:  5  | Resultado obtenido:  8  |  Falló  | Precisión:  51.64 %
# Nº  520  | Resultado esperado:  4  | Resultado obtenido:  9  |  Falló  | Precisión:  51.54 %
# ...
# Nº  9830  | Resultado esperado:  9  | Resultado obtenido:  9  |   OK   | Precisión:  55.66 %
# Nº  9831  | Resultado esperado:  5  | Resultado obtenido:  1  |  Falló  | Precisión:  55.65 %
# Nº  9832  | Resultado esperado:  5  | Resultado obtenido:  1  |  Falló  | Precisión:  55.64 %
# Nº  9833  | Resultado esperado:  2  | Resultado obtenido:  8  |  Falló  | Precisión:  55.64 %
# Nº  9834  | Resultado esperado:  6  | Resultado obtenido:  6  |   OK   | Precisión:  55.64 %
# Nº  9835  | Resultado esperado:  8  | Resultado obtenido:  1  |  Falló  | Precisión:  55.64 %
# Nº  9836  | Resultado esperado:  4  | Resultado obtenido:  8  |  Falló  | Precisión:  55.63 %
# Nº  9837  | Resultado esperado:  1  | Resultado obtenido:  1  |   OK   | Precisión:  55.64 %
# Nº  9838  | Resultado esperado:  7  | Resultado obtenido:  9  |  Falló  | Precisión:  55.63 %
# Nº  9839  | Resultado esperado:  1  | Resultado obtenido:  1  |   OK   | Precisión:  55.64 %
# Nº  9840  | Resultado esperado:  2  | Resultado obtenido:  9  |  Falló  | Precisión:  55.63 %
# Nº  9841  | Resultado esperado:  3  | Resultado obtenido:  8  |  Falló  | Precisión:  55.62 %
# Nº  9842  | Resultado esperado:  5  | Resultado obtenido:  5  |   OK   | Precisión:  55.63 %
# Nº  9843  | Resultado esperado:  6  | Resultado obtenido:  6  |   OK   | Precisión:  55.63 %
# Nº  9844  | Resultado esperado:  9  | Resultado obtenido:  9  |   OK   | Precisión:  55.64 %
# Nº  9845  | Resultado esperado:  1  | Resultado obtenido:  1  |   OK   | Precisión:  55.64 %
# Nº  9846  | Resultado esperado:  1  | Resultado obtenido:  1  |   OK   | Precisión:  55.65 %
# Nº  9847  | Resultado esperado:  1  | Resultado obtenido:  1  |   OK   | Precisión:  55.65 %
# Nº  9848  | Resultado esperado:  2  | Resultado obtenido:  9  |  Falló  | Precisión:  55.65 %
# Nº  9849  | Resultado esperado:  1  | Resultado obtenido:  1  |   OK   | Precisión:  55.65 %
# Nº  9850  | Resultado esperado:  2  | Resultado obtenido:  1  |  Falló  | Precisión:  55.64 %
# Nº  9851  | Resultado esperado:  0  | Resultado obtenido:  0  |   OK   | Precisión:  55.65 %
# Nº  9852  | Resultado esperado:  7  | Resultado obtenido:  7  |   OK   | Precisión:  55.65 %
# Nº  9853  | Resultado esperado:  7  | Resultado obtenido:  9  |  Falló  | Precisión:  55.65 %
# Nº  9854  | Resultado esperado:  5  | Resultado obtenido:  1  |  Falló  | Precisión:  55.64 %
# Nº  9855  | Resultado esperado:  8  | Resultado obtenido:  1  |  Falló  | Precisión:  55.64 %
# Nº  9856  | Resultado esperado:  2  | Resultado obtenido:  8  |  Falló  | Precisión:  55.63 %
# Nº  9857  | Resultado esperado:  9  | Resultado obtenido:  9  |   OK   | Precisión:  55.64 %
# Nº  9858  | Resultado esperado:  8  | Resultado obtenido:  1  |  Falló  | Precisión:  55.63 %
# Nº  9859  | Resultado esperado:  6  | Resultado obtenido:  8  |  Falló  | Precisión:  55.62 %
# Nº  9860  | Resultado esperado:  7  | Resultado obtenido:  9  |  Falló  | Precisión:  55.62 %
# Nº  9861  | Resultado esperado:  3  | Resultado obtenido:  8  |  Falló  | Precisión:  55.61 %
# Nº  9862  | Resultado esperado:  4  | Resultado obtenido:  8  |  Falló  | Precisión:  55.61 %
# Nº  9863  | Resultado esperado:  6  | Resultado obtenido:  6  |   OK   | Precisión:  55.61 %
# Nº  9864  | Resultado esperado:  8  | Resultado obtenido:  1  |  Falló  | Precisión:  55.61 %
# Nº  9865  | Resultado esperado:  7  | Resultado obtenido:  9  |  Falló  | Precisión:  55.6 %
# Nº  9866  | Resultado esperado:  0  | Resultado obtenido:  3  |  Falló  | Precisión:  55.59 %
# Nº  9867  | Resultado esperado:  4  | Resultado obtenido:  4  |   OK   | Precisión:  55.6 %
# Nº  9868  | Resultado esperado:  2  | Resultado obtenido:  8  |  Falló  | Precisión:  55.59 %
# Nº  9869  | Resultado esperado:  7  | Resultado obtenido:  9  |  Falló  | Precisión:  55.59 %
# Nº  9870  | Resultado esperado:  7  | Resultado obtenido:  9  |  Falló  | Precisión:  55.58 %
# Nº  9871  | Resultado esperado:  5  | Resultado obtenido:  1  |  Falló  | Precisión:  55.58 %
# Nº  9872  | Resultado esperado:  4  | Resultado obtenido:  8  |  Falló  | Precisión:  55.57 %
# Nº  9873  | Resultado esperado:  3  | Resultado obtenido:  3  |   OK   | Precisión:  55.58 %
# Nº  9874  | Resultado esperado:  4  | Resultado obtenido:  5  |  Falló  | Precisión:  55.57 %
# Nº  9875  | Resultado esperado:  2  | Resultado obtenido:  8  |  Falló  | Precisión:  55.56 %
# Nº  9876  | Resultado esperado:  8  | Resultado obtenido:  9  |  Falló  | Precisión:  55.56 %
# Nº  9877  | Resultado esperado:  1  | Resultado obtenido:  1  |   OK   | Precisión:  55.56 %
# Nº  9878  | Resultado esperado:  5  | Resultado obtenido:  8  |  Falló  | Precisión:  55.56 %
# Nº  9879  | Resultado esperado:  1  | Resultado obtenido:  1  |   OK   | Precisión:  55.56 %
# Nº  9880  | Resultado esperado:  0  | Resultado obtenido:  8  |  Falló  | Precisión:  55.56 %
# Nº  9881  | Resultado esperado:  2  | Resultado obtenido:  1  |  Falló  | Precisión:  55.55 %
# Nº  9882  | Resultado esperado:  3  | Resultado obtenido:  8  |  Falló  | Precisión:  55.55 %
# Nº  9883  | Resultado esperado:  3  | Resultado obtenido:  8  |  Falló  | Precisión:  55.54 %
# Nº  9884  | Resultado esperado:  5  | Resultado obtenido:  6  |  Falló  | Precisión:  55.53 %
# Nº  9885  | Resultado esperado:  7  | Resultado obtenido:  9  |  Falló  | Precisión:  55.53 %
# Nº  9886  | Resultado esperado:  0  | Resultado obtenido:  0  |   OK   | Precisión:  55.53 %
# Nº  9887  | Resultado esperado:  6  | Resultado obtenido:  6  |   OK   | Precisión:  55.54 %
# Nº  9888  | Resultado esperado:  8  | Resultado obtenido:  1  |  Falló  | Precisión:  55.53 %
# Nº  9889  | Resultado esperado:  6  | Resultado obtenido:  8  |  Falló  | Precisión:  55.53 %
# Nº  9890  | Resultado esperado:  3  | Resultado obtenido:  1  |  Falló  | Precisión:  55.52 %
# Nº  9891  | Resultado esperado:  9  | Resultado obtenido:  9  |   OK   | Precisión:  55.53 %
# Nº  9892  | Resultado esperado:  9  | Resultado obtenido:  9  |   OK   | Precisión:  55.53 %
# Nº  9893  | Resultado esperado:  8  | Resultado obtenido:  1  |  Falló  | Precisión:  55.52 %
# Nº  9894  | Resultado esperado:  2  | Resultado obtenido:  8  |  Falló  | Precisión:  55.52 %
# Nº  9895  | Resultado esperado:  7  | Resultado obtenido:  9  |  Falló  | Precisión:  55.51 %
# Nº  9896  | Resultado esperado:  7  | Resultado obtenido:  9  |  Falló  | Precisión:  55.51 %
# Nº  9897  | Resultado esperado:  1  | Resultado obtenido:  1  |   OK   | Precisión:  55.51 %
# Nº  9898  | Resultado esperado:  0  | Resultado obtenido:  0  |   OK   | Precisión:  55.52 %
# Nº  9899  | Resultado esperado:  1  | Resultado obtenido:  1  |   OK   | Precisión:  55.52 %
# Nº  9900  | Resultado esperado:  7  | Resultado obtenido:  9  |  Falló  | Precisión:  55.52 %
# Nº  9901  | Resultado esperado:  8  | Resultado obtenido:  1  |  Falló  | Precisión:  55.51 %
# Nº  9902  | Resultado esperado:  9  | Resultado obtenido:  8  |  Falló  | Precisión:  55.5 %
# Nº  9903  | Resultado esperado:  0  | Resultado obtenido:  0  |   OK   | Precisión:  55.51 %
# Nº  9904  | Resultado esperado:  1  | Resultado obtenido:  1  |   OK   | Precisión:  55.51 %
# Nº  9905  | Resultado esperado:  2  | Resultado obtenido:  0  |  Falló  | Precisión:  55.51 %
# Nº  9906  | Resultado esperado:  3  | Resultado obtenido:  9  |  Falló  | Precisión:  55.5 %
# Nº  9907  | Resultado esperado:  4  | Resultado obtenido:  8  |  Falló  | Precisión:  55.5 %
# Nº  9908  | Resultado esperado:  5  | Resultado obtenido:  8  |  Falló  | Precisión:  55.49 %
# Nº  9909  | Resultado esperado:  6  | Resultado obtenido:  6  |   OK   | Precisión:  55.5 %
# Nº  9910  | Resultado esperado:  7  | Resultado obtenido:  9  |  Falló  | Precisión:  55.49 %
# Nº  9911  | Resultado esperado:  8  | Resultado obtenido:  8  |   OK   | Precisión:  55.49 %
# Nº  9912  | Resultado esperado:  0  | Resultado obtenido:  0  |   OK   | Precisión:  55.5 %
# Nº  9913  | Resultado esperado:  1  | Resultado obtenido:  1  |   OK   | Precisión:  55.5 %
# Nº  9914  | Resultado esperado:  2  | Resultado obtenido:  8  |  Falló  | Precisión:  55.5 %
# Nº  9915  | Resultado esperado:  3  | Resultado obtenido:  8  |  Falló  | Precisión:  55.49 %
# Nº  9916  | Resultado esperado:  4  | Resultado obtenido:  8  |  Falló  | Precisión:  55.49 %
# Nº  9917  | Resultado esperado:  7  | Resultado obtenido:  9  |  Falló  | Precisión:  55.48 %
# Nº  9918  | Resultado esperado:  8  | Resultado obtenido:  8  |   OK   | Precisión:  55.48 %
# Nº  9919  | Resultado esperado:  9  | Resultado obtenido:  9  |   OK   | Precisión:  55.49 %
# Nº  9920  | Resultado esperado:  7  | Resultado obtenido:  9  |  Falló  | Precisión:  55.48 %
# Nº  9921  | Resultado esperado:  8  | Resultado obtenido:  8  |   OK   | Precisión:  55.49 %
# Nº  9922  | Resultado esperado:  6  | Resultado obtenido:  6  |   OK   | Precisión:  55.49 %
# Nº  9923  | Resultado esperado:  4  | Resultado obtenido:  8  |  Falló  | Precisión:  55.49 %
# Nº  9924  | Resultado esperado:  1  | Resultado obtenido:  1  |   OK   | Precisión:  55.49 %
# Nº  9925  | Resultado esperado:  9  | Resultado obtenido:  7  |  Falló  | Precisión:  55.49 %
# Nº  9926  | Resultado esperado:  3  | Resultado obtenido:  8  |  Falló  | Precisión:  55.48 %
# Nº  9927  | Resultado esperado:  8  | Resultado obtenido:  8  |   OK   | Precisión:  55.49 %
# Nº  9928  | Resultado esperado:  4  | Resultado obtenido:  4  |   OK   | Precisión:  55.49 %
# Nº  9929  | Resultado esperado:  4  | Resultado obtenido:  8  |  Falló  | Precisión:  55.48 %
# Nº  9930  | Resultado esperado:  7  | Resultado obtenido:  9  |  Falló  | Precisión:  55.48 %
# Nº  9931  | Resultado esperado:  0  | Resultado obtenido:  0  |   OK   | Precisión:  55.48 %
# Nº  9932  | Resultado esperado:  1  | Resultado obtenido:  1  |   OK   | Precisión:  55.49 %
# Nº  9933  | Resultado esperado:  9  | Resultado obtenido:  9  |   OK   | Precisión:  55.49 %
# Nº  9934  | Resultado esperado:  2  | Resultado obtenido:  3  |  Falló  | Precisión:  55.49 %
# Nº  9935  | Resultado esperado:  8  | Resultado obtenido:  1  |  Falló  | Precisión:  55.48 %
# Nº  9936  | Resultado esperado:  7  | Resultado obtenido:  9  |  Falló  | Precisión:  55.48 %
# Nº  9937  | Resultado esperado:  8  | Resultado obtenido:  9  |  Falló  | Precisión:  55.47 %
# Nº  9938  | Resultado esperado:  2  | Resultado obtenido:  3  |  Falló  | Precisión:  55.46 %
# Nº  9939  | Resultado esperado:  6  | Resultado obtenido:  6  |   OK   | Precisión:  55.47 %
# Nº  9940  | Resultado esperado:  0  | Resultado obtenido:  0  |   OK   | Precisión:  55.47 %
# Nº  9941  | Resultado esperado:  6  | Resultado obtenido:  0  |  Falló  | Precisión:  55.47 %
# Nº  9942  | Resultado esperado:  5  | Resultado obtenido:  6  |  Falló  | Precisión:  55.46 %
# Nº  9943  | Resultado esperado:  3  | Resultado obtenido:  8  |  Falló  | Precisión:  55.46 %
# Nº  9944  | Resultado esperado:  3  | Resultado obtenido:  8  |  Falló  | Precisión:  55.45 %
# Nº  9945  | Resultado esperado:  3  | Resultado obtenido:  9  |  Falló  | Precisión:  55.44 %
# Nº  9946  | Resultado esperado:  9  | Resultado obtenido:  9  |   OK   | Precisión:  55.45 %
# Nº  9947  | Resultado esperado:  1  | Resultado obtenido:  1  |   OK   | Precisión:  55.45 %
# Nº  9948  | Resultado esperado:  4  | Resultado obtenido:  6  |  Falló  | Precisión:  55.45 %
# Nº  9949  | Resultado esperado:  0  | Resultado obtenido:  0  |   OK   | Precisión:  55.45 %
# Nº  9950  | Resultado esperado:  6  | Resultado obtenido:  6  |   OK   | Precisión:  55.46 %
# Nº  9951  | Resultado esperado:  1  | Resultado obtenido:  1  |   OK   | Precisión:  55.46 %
# Nº  9952  | Resultado esperado:  0  | Resultado obtenido:  0  |   OK   | Precisión:  55.47 %
# Nº  9953  | Resultado esperado:  0  | Resultado obtenido:  0  |   OK   | Precisión:  55.47 %
# Nº  9954  | Resultado esperado:  6  | Resultado obtenido:  6  |   OK   | Precisión:  55.48 %
# Nº  9955  | Resultado esperado:  2  | Resultado obtenido:  0  |  Falló  | Precisión:  55.47 %
# Nº  9956  | Resultado esperado:  1  | Resultado obtenido:  1  |   OK   | Precisión:  55.47 %
# Nº  9957  | Resultado esperado:  1  | Resultado obtenido:  1  |   OK   | Precisión:  55.48 %
# Nº  9958  | Resultado esperado:  7  | Resultado obtenido:  9  |  Falló  | Precisión:  55.47 %
# Nº  9959  | Resultado esperado:  7  | Resultado obtenido:  9  |  Falló  | Precisión:  55.47 %
# Nº  9960  | Resultado esperado:  8  | Resultado obtenido:  8  |   OK   | Precisión:  55.47 %
# Nº  9961  | Resultado esperado:  4  | Resultado obtenido:  9  |  Falló  | Precisión:  55.47 %
# Nº  9962  | Resultado esperado:  6  | Resultado obtenido:  6  |   OK   | Precisión:  55.47 %
# Nº  9963  | Resultado esperado:  0  | Resultado obtenido:  0  |   OK   | Precisión:  55.48 %
# Nº  9964  | Resultado esperado:  7  | Resultado obtenido:  9  |  Falló  | Precisión:  55.47 %
# Nº  9965  | Resultado esperado:  0  | Resultado obtenido:  0  |   OK   | Precisión:  55.47 %
# Nº  9966  | Resultado esperado:  3  | Resultado obtenido:  3  |   OK   | Precisión:  55.48 %
# Nº  9967  | Resultado esperado:  6  | Resultado obtenido:  6  |   OK   | Precisión:  55.48 %
# Nº  9968  | Resultado esperado:  8  | Resultado obtenido:  8  |   OK   | Precisión:  55.49 %
# Nº  9969  | Resultado esperado:  7  | Resultado obtenido:  9  |  Falló  | Precisión:  55.48 %
# Nº  9970  | Resultado esperado:  1  | Resultado obtenido:  1  |   OK   | Precisión:  55.49 %
# Nº  9971  | Resultado esperado:  5  | Resultado obtenido:  6  |  Falló  | Precisión:  55.48 %
# Nº  9972  | Resultado esperado:  2  | Resultado obtenido:  0  |  Falló  | Precisión:  55.48 %
# Nº  9973  | Resultado esperado:  4  | Resultado obtenido:  8  |  Falló  | Precisión:  55.47 %
# Nº  9974  | Resultado esperado:  9  | Resultado obtenido:  9  |   OK   | Precisión:  55.47 %
# Nº  9975  | Resultado esperado:  4  | Resultado obtenido:  8  |  Falló  | Precisión:  55.47 %
# Nº  9976  | Resultado esperado:  3  | Resultado obtenido:  8  |  Falló  | Precisión:  55.46 %
# Nº  9977  | Resultado esperado:  6  | Resultado obtenido:  6  |   OK   | Precisión:  55.47 %
# Nº  9978  | Resultado esperado:  4  | Resultado obtenido:  9  |  Falló  | Precisión:  55.46 %
# Nº  9979  | Resultado esperado:  1  | Resultado obtenido:  1  |   OK   | Precisión:  55.47 %
# Nº  9980  | Resultado esperado:  7  | Resultado obtenido:  9  |  Falló  | Precisión:  55.46 %
# Nº  9981  | Resultado esperado:  2  | Resultado obtenido:  3  |  Falló  | Precisión:  55.46 %
# Nº  9982  | Resultado esperado:  6  | Resultado obtenido:  6  |   OK   | Precisión:  55.46 %
# Nº  9983  | Resultado esperado:  5  | Resultado obtenido:  6  |  Falló  | Precisión:  55.45 %
# Nº  9984  | Resultado esperado:  0  | Resultado obtenido:  0  |   OK   | Precisión:  55.46 %
# Nº  9985  | Resultado esperado:  1  | Resultado obtenido:  1  |   OK   | Precisión:  55.46 %
# Nº  9986  | Resultado esperado:  2  | Resultado obtenido:  8  |  Falló  | Precisión:  55.46 %
# Nº  9987  | Resultado esperado:  3  | Resultado obtenido:  8  |  Falló  | Precisión:  55.45 %
# Nº  9988  | Resultado esperado:  4  | Resultado obtenido:  9  |  Falló  | Precisión:  55.45 %
# Nº  9989  | Resultado esperado:  5  | Resultado obtenido:  8  |  Falló  | Precisión:  55.44 %
# Nº  9990  | Resultado esperado:  6  | Resultado obtenido:  6  |   OK   | Precisión:  55.45 %
# Nº  9991  | Resultado esperado:  7  | Resultado obtenido:  9  |  Falló  | Precisión:  55.44 %
# Nº  9992  | Resultado esperado:  8  | Resultado obtenido:  8  |   OK   | Precisión:  55.44 %
# Nº  9993  | Resultado esperado:  9  | Resultado obtenido:  9  |   OK   | Precisión:  55.45 %
# Nº  9994  | Resultado esperado:  0  | Resultado obtenido:  0  |   OK   | Precisión:  55.45 %
# Nº  9995  | Resultado esperado:  1  | Resultado obtenido:  1  |   OK   | Precisión:  55.46 %
# Nº  9996  | Resultado esperado:  2  | Resultado obtenido:  8  |  Falló  | Precisión:  55.45 %
# Nº  9997  | Resultado esperado:  3  | Resultado obtenido:  8  |  Falló  | Precisión:  55.45 %
# Nº  9998  | Resultado esperado:  4  | Resultado obtenido:  9  |  Falló  | Precisión:  55.44 %
# Nº  9999  | Resultado esperado:  5  | Resultado obtenido:  8  |  Falló  | Precisión:  55.44 %
# Nº  10000  | Resultado esperado:  6  | Resultado obtenido:  6  |   OK   | Precisión:  55.44 %

# %% [markdown]
# ## 10. Resultados finales
#
# Mostramos el resumen de tiempos y precisión.

# %%
# Mostrar resultados finales
print("-------------------------------")
print("Resultados")
print("-------------------------------")
print("Muestras de entrenamiento: ", muestras_entrenamiento)
print("Tiempo de entrenamiento: ", round(tiempo_entrenamiento, 2), " s")
print("Muestras de prueba: ", muestras_prueba)
print("Tiempo de prueba: ", round(tiempo_prueba, 2), " s")
print("Precisión en prueba: ", round((resultados_validos / muestras_prueba) * 100, 2), "%")
# Out:
# -------------------------------
# Resultados
# -------------------------------
# Muestras de entrenamiento:  50000
# Tiempo de entrenamiento:  0.88  s
# Muestras de prueba:  10000
# Tiempo de prueba:  2.57  s
# Precisión en prueba:  55.44 %
