# %% [markdown]
# # 1. Clasificación de dígitos MNIST con KNeighborsClassifier
#
# Este notebook muestra cómo entrenar y evaluar un clasificador KNN sobre el dataset MNIST usando bibliotecas de Python.

# %% [markdown]
# ## 2. Importar bibliotecas necesarias
#
# Importamos pandas, numpy, time y el clasificador KNeighborsClassifier de scikit-learn.

# %%
# Importar bibliotecas necesarias
import pandas as pd
import numpy as np
import time
from sklearn.neighbors import KNeighborsClassifier

# %% [markdown]
# ## 3. Definir parámetros globales
#
# Establecemos el número de muestras para entrenamiento y prueba.

# %%
# Definir parámetros globales
muestras_entrenamiento = 50000  # Número de muestras de entrenamiento
muestras_prueba = 10000         # Número de muestras de prueba

# %% [markdown]
# ## 4. Inicializar variables para medir tiempos
#
# Estas variables nos permitirán medir el tiempo de entrenamiento y prueba.

# %%
# Inicializar variables para medir tiempos
inicio_tiempo_entrenamiento = 0
fin_tiempo_entrenamiento = 0
tiempo_entrenamiento = 0

inicio_tiempo_prueba = 0
fin_tiempo_prueba = 0
tiempo_prueba = 0

# %% [markdown]
# ## 5. Función para cargar el dataset
#
# Esta función lee un archivo CSV y devuelve los datos normalizados y las etiquetas.

# %%
def cargar_dataset(nombre_archivo, muestras):
    """
    Carga un dataset CSV y devuelve los datos normalizados y las etiquetas.
    """
    x = []  # Datos de entrada
    y = []  # Etiquetas
    datos = pd.read_csv(nombre_archivo)
    y = np.array(datos.iloc[0:muestras, 0])  # Primera columna: etiquetas
    x = np.array(datos.iloc[0:muestras, 1:]) / 255  # Normalización
    return x, y

# %% [markdown]
# ## 6. Cargar los datos de entrenamiento y prueba
#
# Usamos la función definida para cargar los datos.

# %%
# Cargar los datos de entrenamiento y prueba
x_entrenamiento, y_entrenamiento = cargar_dataset("../../datasets/mnist/mnist_train.csv", muestras_entrenamiento)
x_prueba, y_prueba = cargar_dataset("../../datasets/mnist/mnist_test.csv", muestras_prueba)

# %% [markdown]
# ## 7. Crear y entrenar el modelo KNN
#
# Entrenamos el modelo y medimos el tiempo de entrenamiento.

# %%
# Crear y entrenar el modelo KNN
knn = KNeighborsClassifier(n_neighbors=3)
inicio_tiempo_entrenamiento = time.time()
knn.fit(x_entrenamiento, y_entrenamiento)
fin_tiempo_entrenamiento = time.time()
tiempo_entrenamiento = fin_tiempo_entrenamiento - inicio_tiempo_entrenamiento
print(f"Tiempo de entrenamiento: {tiempo_entrenamiento:.2f} s")
# Out:
# Tiempo de entrenamiento: 0.17 s

# %% [markdown]
# ## 8. Evaluación global rápida del modelo
#
# Calculamos la precisión del modelo sobre todo el conjunto de prueba de una sola vez usando `knn.score` y medimos el tiempo de inferencia total.

# %%
# Evaluación simple sobre todo el conjunto de prueba y cálculo del tiempo de inferencia
import time
inicio_inferencia = time.time()
precision = knn.score(x_prueba, y_prueba)
fin_inferencia = time.time()
tiempo_inferencia = fin_inferencia - inicio_inferencia
print(f"Precisión global (score): {precision:.4f}")
print(f"Tiempo de inferencia sobre todo el conjunto de prueba: {tiempo_inferencia:.4f} s")
# Out:
# Precisión global (score): 0.9681
# Tiempo de inferencia sobre todo el conjunto de prueba: 3.1788 s

# %% [markdown]
# ## 9. Evaluar el modelo sobre el dataset de prueba
#
# Calculamos la precisión y mostramos resultados para cada muestra.

# %%
# Evaluar el modelo sobre el dataset de prueba
resultados_validos = 0
inicio_tiempo_prueba = time.time()
for i in range(len(y_prueba)):
    resultado_esperado = int(y_prueba[int(i)])
    resultado_obtenido = knn.predict(x_prueba[int(i)].reshape(1, -1)).item()
    resultado_texto = "Falló"
    if resultado_obtenido == resultado_esperado:
        resultados_validos += 1
        resultado_texto = " OK "
    # Imprimir solo los primeros 20 resultados
    print("Nº ", i + 1, " | Resultado esperado: ", resultado_esperado, " | Resultado obtenido: ", resultado_obtenido, " | ", resultado_texto,
              " | Precisión: ", round((resultados_validos / (i + 1)) * 100, 2), "%")
fin_tiempo_prueba = time.time()
tiempo_prueba = fin_tiempo_prueba - inicio_tiempo_prueba
# Out:
# Nº  1  | Expected result:  7  | Obtained result:  7  |   OK   | Accuracy:  100.0 %
# Nº  2  | Expected result:  2  | Obtained result:  2  |   OK   | Accuracy:  100.0 %
# Nº  3  | Expected result:  1  | Obtained result:  1  |   OK   | Accuracy:  100.0 %
# Nº  4  | Expected result:  0  | Obtained result:  0  |   OK   | Accuracy:  100.0 %
# Nº  5  | Expected result:  4  | Obtained result:  4  |   OK   | Accuracy:  100.0 %
# Nº  6  | Expected result:  1  | Obtained result:  1  |   OK   | Accuracy:  100.0 %
# Nº  6  | Expected result:  1  | Obtained result:  1  |   OK   | Accuracy:  100.0 %
# Nº  7  | Expected result:  4  | Obtained result:  4  |   OK   | Accuracy:  100.0 %
# Nº  8  | Expected result:  9  | Obtained result:  9  |   OK   | Accuracy:  100.0 %
# Nº  9  | Expected result:  5  | Obtained result:  5  |   OK   | Accuracy:  100.0 %
# Nº  10  | Expected result:  9  | Obtained result:  9  |   OK   | Accuracy:  100.0 %
# Nº  7  | Expected result:  4  | Obtained result:  4  |   OK   | Accuracy:  100.0 %
# Nº  8  | Expected result:  9  | Obtained result:  9  |   OK   | Accuracy:  100.0 %
# Nº  9  | Expected result:  5  | Obtained result:  5  |   OK   | Accuracy:  100.0 %
# Nº  10  | Expected result:  9  | Obtained result:  9  |   OK   | Accuracy:  100.0 %
# Nº  11  | Expected result:  0  | Obtained result:  0  |   OK   | Accuracy:  100.0 %
# Nº  12  | Expected result:  6  | Obtained result:  6  |   OK   | Accuracy:  100.0 %
# Nº  11  | Expected result:  0  | Obtained result:  0  |   OK   | Accuracy:  100.0 %
# Nº  12  | Expected result:  6  | Obtained result:  6  |   OK   | Accuracy:  100.0 %
# Nº  13  | Expected result:  9  | Obtained result:  9  |   OK   | Accuracy:  100.0 %
# Nº  14  | Expected result:  0  | Obtained result:  0  |   OK   | Accuracy:  100.0 %
# Nº  15  | Expected result:  1  | Obtained result:  1  |   OK   | Accuracy:  100.0 %
# Nº  13  | Expected result:  9  | Obtained result:  9  |   OK   | Accuracy:  100.0 %
# Nº  14  | Expected result:  0  | Obtained result:  0  |   OK   | Accuracy:  100.0 %
# Nº  15  | Expected result:  1  | Obtained result:  1  |   OK   | Accuracy:  100.0 %
# Nº  16  | Expected result:  5  | Obtained result:  5  |   OK   | Accuracy:  100.0 %
# Nº  17  | Expected result:  9  | Obtained result:  9  |   OK   | Accuracy:  100.0 %
# Nº  18  | Expected result:  7  | Obtained result:  7  |   OK   | Accuracy:  100.0 %
# Nº  16  | Expected result:  5  | Obtained result:  5  |   OK   | Accuracy:  100.0 %
# Nº  17  | Expected result:  9  | Obtained result:  9  |   OK   | Accuracy:  100.0 %
# Nº  18  | Expected result:  7  | Obtained result:  7  |   OK   | Accuracy:  100.0 %
# Nº  19  | Expected result:  3  | Obtained result:  3  |   OK   | Accuracy:  100.0 %
# Nº  20  | Expected result:  4  | Obtained result:  4  |   OK   | Accuracy:  100.0 %
# Nº  19  | Expected result:  3  | Obtained result:  3  |   OK   | Accuracy:  100.0 %
# Nº  20  | Expected result:  4  | Obtained result:  4  |   OK   | Accuracy:  100.0 %
# Nº  21  | Expected result:  9  | Obtained result:  9  |   OK   | Accuracy:  100.0 %
# Nº  22  | Expected result:  6  | Obtained result:  6  |   OK   | Accuracy:  100.0 %
# Nº  23  | Expected result:  6  | Obtained result:  6  |   OK   | Accuracy:  100.0 %
# Nº  21  | Expected result:  9  | Obtained result:  9  |   OK   | Accuracy:  100.0 %
# Nº  22  | Expected result:  6  | Obtained result:  6  |   OK   | Accuracy:  100.0 %
# Nº  23  | Expected result:  6  | Obtained result:  6  |   OK   | Accuracy:  100.0 %
# Nº  24  | Expected result:  5  | Obtained result:  5  |   OK   | Accuracy:  100.0 %
# Nº  25  | Expected result:  4  | Obtained result:  4  |   OK   | Accuracy:  100.0 %
# Nº  24  | Expected result:  5  | Obtained result:  5  |   OK   | Accuracy:  100.0 %
# Nº  25  | Expected result:  4  | Obtained result:  4  |   OK   | Accuracy:  100.0 %
# Nº  26  | Expected result:  0  | Obtained result:  0  |   OK   | Accuracy:  100.0 %
# Nº  27  | Expected result:  7  | Obtained result:  7  |   OK   | Accuracy:  100.0 %
# Nº  28  | Expected result:  4  | Obtained result:  4  |   OK   | Accuracy:  100.0 %
# Nº  26  | Expected result:  0  | Obtained result:  0  |   OK   | Accuracy:  100.0 %
# Nº  27  | Expected result:  7  | Obtained result:  7  |   OK   | Accuracy:  100.0 %
# Nº  28  | Expected result:  4  | Obtained result:  4  |   OK   | Accuracy:  100.0 %
# Nº  29  | Expected result:  0  | Obtained result:  0  |   OK   | Accuracy:  100.0 %
# Nº  30  | Expected result:  1  | Obtained result:  1  |   OK   | Accuracy:  100.0 %
# Nº  31  | Expected result:  3  | Obtained result:  3  |   OK   | Accuracy:  100.0 %
# Nº  29  | Expected result:  0  | Obtained result:  0  |   OK   | Accuracy:  100.0 %
# Nº  30  | Expected result:  1  | Obtained result:  1  |   OK   | Accuracy:  100.0 %
# Nº  31  | Expected result:  3  | Obtained result:  3  |   OK   | Accuracy:  100.0 %
# Nº  32  | Expected result:  1  | Obtained result:  1  |   OK   | Accuracy:  100.0 %
# Nº  33  | Expected result:  3  | Obtained result:  3  |   OK   | Accuracy:  100.0 %
# Nº  32  | Expected result:  1  | Obtained result:  1  |   OK   | Accuracy:  100.0 %
# Nº  33  | Expected result:  3  | Obtained result:  3  |   OK   | Accuracy:  100.0 %
# Nº  34  | Expected result:  4  | Obtained result:  4  |   OK   | Accuracy:  100.0 %
# Nº  35  | Expected result:  7  | Obtained result:  7  |   OK   | Accuracy:  100.0 %
# Nº  36  | Expected result:  2  | Obtained result:  2  |   OK   | Accuracy:  100.0 %
# Nº  34  | Expected result:  4  | Obtained result:  4  |   OK   | Accuracy:  100.0 %
# Nº  35  | Expected result:  7  | Obtained result:  7  |   OK   | Accuracy:  100.0 %
# Nº  36  | Expected result:  2  | Obtained result:  2  |   OK   | Accuracy:  100.0 %
# Nº  37  | Expected result:  7  | Obtained result:  7  |   OK   | Accuracy:  100.0 %
# Nº  38  | Expected result:  1  | Obtained result:  1  |   OK   | Accuracy:  100.0 %
# Nº  37  | Expected result:  7  | Obtained result:  7  |   OK   | Accuracy:  100.0 %
# Nº  38  | Expected result:  1  | Obtained result:  1  |   OK   | Accuracy:  100.0 %
# Nº  39  | Expected result:  2  | Obtained result:  2  |   OK   | Accuracy:  100.0 %
# Nº  40  | Expected result:  1  | Obtained result:  1  |   OK   | Accuracy:  100.0 %
# Nº  41  | Expected result:  1  | Obtained result:  1  |   OK   | Accuracy:  100.0 %
# Nº  39  | Expected result:  2  | Obtained result:  2  |   OK   | Accuracy:  100.0 %
# Nº  40  | Expected result:  1  | Obtained result:  1  |   OK   | Accuracy:  100.0 %
# Nº  41  | Expected result:  1  | Obtained result:  1  |   OK   | Accuracy:  100.0 %
# Nº  42  | Expected result:  7  | Obtained result:  7  |   OK   | Accuracy:  100.0 %
# Nº  43  | Expected result:  4  | Obtained result:  4  |   OK   | Accuracy:  100.0 %
# Nº  42  | Expected result:  7  | Obtained result:  7  |   OK   | Accuracy:  100.0 %
# Nº  43  | Expected result:  4  | Obtained result:  4  |   OK   | Accuracy:  100.0 %
# Nº  44  | Expected result:  2  | Obtained result:  2  |   OK   | Accuracy:  100.0 %
# Nº  45  | Expected result:  3  | Obtained result:  3  |   OK   | Accuracy:  100.0 %
# Nº  46  | Expected result:  5  | Obtained result:  5  |   OK   | Accuracy:  100.0 %
# Nº  44  | Expected result:  2  | Obtained result:  2  |   OK   | Accuracy:  100.0 %
# Nº  45  | Expected result:  3  | Obtained result:  3  |   OK   | Accuracy:  100.0 %
# Nº  46  | Expected result:  5  | Obtained result:  5  |   OK   | Accuracy:  100.0 %
# Nº  47  | Expected result:  1  | Obtained result:  1  |   OK   | Accuracy:  100.0 %
# Nº  48  | Expected result:  2  | Obtained result:  2  |   OK   | Accuracy:  100.0 %
# Nº  47  | Expected result:  1  | Obtained result:  1  |   OK   | Accuracy:  100.0 %
# Nº  48  | Expected result:  2  | Obtained result:  2  |   OK   | Accuracy:  100.0 %
# Nº  49  | Expected result:  4  | Obtained result:  4  |   OK   | Accuracy:  100.0 %
# Nº  50  | Expected result:  4  | Obtained result:  4  |   OK   | Accuracy:  100.0 %
# Nº  51  | Expected result:  6  | Obtained result:  6  |   OK   | Accuracy:  100.0 %
# Nº  49  | Expected result:  4  | Obtained result:  4  |   OK   | Accuracy:  100.0 %
# Nº  50  | Expected result:  4  | Obtained result:  4  |   OK   | Accuracy:  100.0 %
# Nº  51  | Expected result:  6  | Obtained result:  6  |   OK   | Accuracy:  100.0 %
# Nº  52  | Expected result:  3  | Obtained result:  3  |   OK   | Accuracy:  100.0 %
# Nº  53  | Expected result:  5  | Obtained result:  5  |   OK   | Accuracy:  100.0 %
# Nº  52  | Expected result:  3  | Obtained result:  3  |   OK   | Accuracy:  100.0 %
# Nº  53  | Expected result:  5  | Obtained result:  5  |   OK   | Accuracy:  100.0 %
# Nº  54  | Expected result:  5  | Obtained result:  5  |   OK   | Accuracy:  100.0 %
# Nº  55  | Expected result:  6  | Obtained result:  6  |   OK   | Accuracy:  100.0 %
# Nº  56  | Expected result:  0  | Obtained result:  0  |   OK   | Accuracy:  100.0 %
# Nº  57  | Expected result:  4  | Obtained result:  4  |   OK   | Accuracy:  100.0 %
# Nº  54  | Expected result:  5  | Obtained result:  5  |   OK   | Accuracy:  100.0 %
# Nº  55  | Expected result:  6  | Obtained result:  6  |   OK   | Accuracy:  100.0 %
# Nº  56  | Expected result:  0  | Obtained result:  0  |   OK   | Accuracy:  100.0 %
# Nº  57  | Expected result:  4  | Obtained result:  4  |   OK   | Accuracy:  100.0 %
# Nº  58  | Expected result:  1  | Obtained result:  1  |   OK   | Accuracy:  100.0 %
# Nº  58  | Expected result:  1  | Obtained result:  1  |   OK   | Accuracy:  100.0 %
# Nº  59  | Expected result:  9  | Obtained result:  9  |   OK   | Accuracy:  100.0 %
# Nº  60  | Expected result:  5  | Obtained result:  5  |   OK   | Accuracy:  100.0 %
# Nº  61  | Expected result:  7  | Obtained result:  7  |   OK   | Accuracy:  100.0 %
# Nº  62  | Expected result:  8  | Obtained result:  8  |   OK   | Accuracy:  100.0 %
# Nº  63  | Expected result:  9  | Obtained result:  9  |   OK   | Accuracy:  100.0 %
# Nº  59  | Expected result:  9  | Obtained result:  9  |   OK   | Accuracy:  100.0 %
# Nº  60  | Expected result:  5  | Obtained result:  5  |   OK   | Accuracy:  100.0 %
# Nº  61  | Expected result:  7  | Obtained result:  7  |   OK   | Accuracy:  100.0 %
# Nº  62  | Expected result:  8  | Obtained result:  8  |   OK   | Accuracy:  100.0 %
# Nº  63  | Expected result:  9  | Obtained result:  9  |   OK   | Accuracy:  100.0 %
# Nº  64  | Expected result:  3  | Obtained result:  3  |   OK   | Accuracy:  100.0 %
# Nº  64  | Expected result:  3  | Obtained result:  3  |   OK   | Accuracy:  100.0 %
# Nº  65  | Expected result:  7  | Obtained result:  7  |   OK   | Accuracy:  100.0 %
# Nº  66  | Expected result:  4  | Obtained result:  4  |   OK   | Accuracy:  100.0 %
# Nº  67  | Expected result:  6  | Obtained result:  6  |   OK   | Accuracy:  100.0 %
# Nº  68  | Expected result:  4  | Obtained result:  4  |   OK   | Accuracy:  100.0 %
# Nº  65  | Expected result:  7  | Obtained result:  7  |   OK   | Accuracy:  100.0 %
# Nº  66  | Expected result:  4  | Obtained result:  4  |   OK   | Accuracy:  100.0 %
# Nº  67  | Expected result:  6  | Obtained result:  6  |   OK   | Accuracy:  100.0 %
# Nº  68  | Expected result:  4  | Obtained result:  4  |   OK   | Accuracy:  100.0 %
# Nº  69  | Expected result:  3  | Obtained result:  3  |   OK   | Accuracy:  100.0 %
# Nº  70  | Expected result:  0  | Obtained result:  0  |   OK   | Accuracy:  100.0 %
# Nº  69  | Expected result:  3  | Obtained result:  3  |   OK   | Accuracy:  100.0 %
# Nº  70  | Expected result:  0  | Obtained result:  0  |   OK   | Accuracy:  100.0 %
# Nº  71  | Expected result:  7  | Obtained result:  7  |   OK   | Accuracy:  100.0 %
# Nº  72  | Expected result:  0  | Obtained result:  0  |   OK   | Accuracy:  100.0 %
# Nº  73  | Expected result:  2  | Obtained result:  2  |   OK   | Accuracy:  100.0 %
# Nº  71  | Expected result:  7  | Obtained result:  7  |   OK   | Accuracy:  100.0 %
# Nº  72  | Expected result:  0  | Obtained result:  0  |   OK   | Accuracy:  100.0 %
# Nº  73  | Expected result:  2  | Obtained result:  2  |   OK   | Accuracy:  100.0 %
# Nº  74  | Expected result:  9  | Obtained result:  9  |   OK   | Accuracy:  100.0 %
# Nº  75  | Expected result:  1  | Obtained result:  1  |   OK   | Accuracy:  100.0 %
# Nº  74  | Expected result:  9  | Obtained result:  9  |   OK   | Accuracy:  100.0 %
# Nº  75  | Expected result:  1  | Obtained result:  1  |   OK   | Accuracy:  100.0 %
# Nº  76  | Expected result:  7  | Obtained result:  7  |   OK   | Accuracy:  100.0 %
# Nº  77  | Expected result:  3  | Obtained result:  3  |   OK   | Accuracy:  100.0 %
# Nº  78  | Expected result:  2  | Obtained result:  2  |   OK   | Accuracy:  100.0 %
# Nº  79  | Expected result:  9  | Obtained result:  9  |   OK   | Accuracy:  100.0 %
# Nº  76  | Expected result:  7  | Obtained result:  7  |   OK   | Accuracy:  100.0 %
# Nº  77  | Expected result:  3  | Obtained result:  3  |   OK   | Accuracy:  100.0 %
# Nº  78  | Expected result:  2  | Obtained result:  2  |   OK   | Accuracy:  100.0 %
# Nº  79  | Expected result:  9  | Obtained result:  9  |   OK   | Accuracy:  100.0 %
# Nº  80  | Expected result:  7  | Obtained result:  7  |   OK   | Accuracy:  100.0 %
# Nº  81  | Expected result:  7  | Obtained result:  7  |   OK   | Accuracy:  100.0 %
# Nº  80  | Expected result:  7  | Obtained result:  7  |   OK   | Accuracy:  100.0 %
# Nº  81  | Expected result:  7  | Obtained result:  7  |   OK   | Accuracy:  100.0 %
# Nº  82  | Expected result:  6  | Obtained result:  6  |   OK   | Accuracy:  100.0 %
# Nº  83  | Expected result:  2  | Obtained result:  2  |   OK   | Accuracy:  100.0 %
# Nº  84  | Expected result:  7  | Obtained result:  7  |   OK   | Accuracy:  100.0 %
# Nº  82  | Expected result:  6  | Obtained result:  6  |   OK   | Accuracy:  100.0 %
# Nº  83  | Expected result:  2  | Obtained result:  2  |   OK   | Accuracy:  100.0 %
# Nº  84  | Expected result:  7  | Obtained result:  7  |   OK   | Accuracy:  100.0 %
# Nº  85  | Expected result:  8  | Obtained result:  8  |   OK   | Accuracy:  100.0 %
# Nº  86  | Expected result:  4  | Obtained result:  4  |   OK   | Accuracy:  100.0 %
# Nº  85  | Expected result:  8  | Obtained result:  8  |   OK   | Accuracy:  100.0 %
# Nº  86  | Expected result:  4  | Obtained result:  4  |   OK   | Accuracy:  100.0 %
# Nº  87  | Expected result:  7  | Obtained result:  7  |   OK   | Accuracy:  100.0 %
# Nº  88  | Expected result:  3  | Obtained result:  3  |   OK   | Accuracy:  100.0 %
# Nº  89  | Expected result:  6  | Obtained result:  6  |   OK   | Accuracy:  100.0 %
# Nº  87  | Expected result:  7  | Obtained result:  7  |   OK   | Accuracy:  100.0 %
# Nº  88  | Expected result:  3  | Obtained result:  3  |   OK   | Accuracy:  100.0 %
# Nº  89  | Expected result:  6  | Obtained result:  6  |   OK   | Accuracy:  100.0 %
# Nº  90  | Expected result:  1  | Obtained result:  1  |   OK   | Accuracy:  100.0 %
# Nº  91  | Expected result:  3  | Obtained result:  3  |   OK   | Accuracy:  100.0 %
# Nº  90  | Expected result:  1  | Obtained result:  1  |   OK   | Accuracy:  100.0 %
# Nº  91  | Expected result:  3  | Obtained result:  3  |   OK   | Accuracy:  100.0 %
# Nº  92  | Expected result:  6  | Obtained result:  6  |   OK   | Accuracy:  100.0 %
# Nº  93  | Expected result:  9  | Obtained result:  9  |   OK   | Accuracy:  100.0 %
# Nº  94  | Expected result:  3  | Obtained result:  3  |   OK   | Accuracy:  100.0 %
# Nº  92  | Expected result:  6  | Obtained result:  6  |   OK   | Accuracy:  100.0 %
# Nº  93  | Expected result:  9  | Obtained result:  9  |   OK   | Accuracy:  100.0 %
# Nº  94  | Expected result:  3  | Obtained result:  3  |   OK   | Accuracy:  100.0 %
# Nº  95  | Expected result:  1  | Obtained result:  1  |   OK   | Accuracy:  100.0 %
# Nº  96  | Expected result:  4  | Obtained result:  4  |   OK   | Accuracy:  100.0 %
# Nº  95  | Expected result:  1  | Obtained result:  1  |   OK   | Accuracy:  100.0 %
# Nº  96  | Expected result:  4  | Obtained result:  4  |   OK   | Accuracy:  100.0 %
# Nº  97  | Expected result:  1  | Obtained result:  1  |   OK   | Accuracy:  100.0 %
# Nº  98  | Expected result:  7  | Obtained result:  7  |   OK   | Accuracy:  100.0 %
# Nº  99  | Expected result:  6  | Obtained result:  6  |   OK   | Accuracy:  100.0 %
# Nº  97  | Expected result:  1  | Obtained result:  1  |   OK   | Accuracy:  100.0 %
# Nº  98  | Expected result:  7  | Obtained result:  7  |   OK   | Accuracy:  100.0 %
# Nº  99  | Expected result:  6  | Obtained result:  6  |   OK   | Accuracy:  100.0 %
# Nº  100  | Expected result:  9  | Obtained result:  9  |   OK   | Accuracy:  100.0 %
# Nº  101  | Expected result:  6  | Obtained result:  6  |   OK   | Accuracy:  100.0 %
# Nº  100  | Expected result:  9  | Obtained result:  9  |   OK   | Accuracy:  100.0 %
# Nº  101  | Expected result:  6  | Obtained result:  6  |   OK   | Accuracy:  100.0 %
# Nº  102  | Expected result:  0  | Obtained result:  0  |   OK   | Accuracy:  100.0 %
# Nº  103  | Expected result:  5  | Obtained result:  5  |   OK   | Accuracy:  100.0 %
# Nº  104  | Expected result:  4  | Obtained result:  4  |   OK   | Accuracy:  100.0 %
# Nº  102  | Expected result:  0  | Obtained result:  0  |   OK   | Accuracy:  100.0 %
# Nº  103  | Expected result:  5  | Obtained result:  5  |   OK   | Accuracy:  100.0 %
# Nº  104  | Expected result:  4  | Obtained result:  4  |   OK   | Accuracy:  100.0 %
# Nº  105  | Expected result:  9  | Obtained result:  9  |   OK   | Accuracy:  100.0 %
# Nº  106  | Expected result:  9  | Obtained result:  9  |   OK   | Accuracy:  100.0 %
# Nº  105  | Expected result:  9  | Obtained result:  9  |   OK   | Accuracy:  100.0 %
# Nº  106  | Expected result:  9  | Obtained result:  9  |   OK   | Accuracy:  100.0 %
# Nº  107  | Expected result:  2  | Obtained result:  2  |   OK   | Accuracy:  100.0 %
# Nº  108  | Expected result:  1  | Obtained result:  1  |   OK   | Accuracy:  100.0 %
# Nº  109  | Expected result:  9  | Obtained result:  9  |   OK   | Accuracy:  100.0 %
# Nº  107  | Expected result:  2  | Obtained result:  2  |   OK   | Accuracy:  100.0 %
# Nº  108  | Expected result:  1  | Obtained result:  1  |   OK   | Accuracy:  100.0 %
# Nº  109  | Expected result:  9  | Obtained result:  9  |   OK   | Accuracy:  100.0 %
# Nº  110  | Expected result:  4  | Obtained result:  4  |   OK   | Accuracy:  100.0 %
# Nº  111  | Expected result:  8  | Obtained result:  8  |   OK   | Accuracy:  100.0 %
# Nº  110  | Expected result:  4  | Obtained result:  4  |   OK   | Accuracy:  100.0 %
# Nº  111  | Expected result:  8  | Obtained result:  8  |   OK   | Accuracy:  100.0 %
# Nº  112  | Expected result:  7  | Obtained result:  7  |   OK   | Accuracy:  100.0 %
# Nº  113  | Expected result:  3  | Obtained result:  3  |   OK   | Accuracy:  100.0 %
# Nº  114  | Expected result:  9  | Obtained result:  9  |   OK   | Accuracy:  100.0 %
# Nº  112  | Expected result:  7  | Obtained result:  7  |   OK   | Accuracy:  100.0 %
# Nº  113  | Expected result:  3  | Obtained result:  3  |   OK   | Accuracy:  100.0 %
# Nº  114  | Expected result:  9  | Obtained result:  9  |   OK   | Accuracy:  100.0 %
# Nº  115  | Expected result:  7  | Obtained result:  7  |   OK   | Accuracy:  100.0 %
# Nº  116  | Expected result:  4  | Obtained result:  9  |  Fail  | Accuracy:  99.14 %
# Nº  115  | Expected result:  7  | Obtained result:  7  |   OK   | Accuracy:  100.0 %
# Nº  116  | Expected result:  4  | Obtained result:  9  |  Fail  | Accuracy:  99.14 %
# Nº  117  | Expected result:  4  | Obtained result:  4  |   OK   | Accuracy:  99.15 %
# Nº  118  | Expected result:  4  | Obtained result:  4  |   OK   | Accuracy:  99.15 %
# Nº  119  | Expected result:  9  | Obtained result:  9  |   OK   | Accuracy:  99.16 %
# Nº  117  | Expected result:  4  | Obtained result:  4  |   OK   | Accuracy:  99.15 %
# Nº  118  | Expected result:  4  | Obtained result:  4  |   OK   | Accuracy:  99.15 %
# Nº  119  | Expected result:  9  | Obtained result:  9  |   OK   | Accuracy:  99.16 %
# Nº  120  | Expected result:  2  | Obtained result:  2  |   OK   | Accuracy:  99.17 %
# Nº  121  | Expected result:  5  | Obtained result:  5  |   OK   | Accuracy:  99.17 %
# Nº  120  | Expected result:  2  | Obtained result:  2  |   OK   | Accuracy:  99.17 %
# Nº  121  | Expected result:  5  | Obtained result:  5  |   OK   | Accuracy:  99.17 %
# Nº  122  | Expected result:  4  | Obtained result:  4  |   OK   | Accuracy:  99.18 %
# Nº  123  | Expected result:  7  | Obtained result:  7  |   OK   | Accuracy:  99.19 %
# Nº  124  | Expected result:  6  | Obtained result:  6  |   OK   | Accuracy:  99.19 %
# Nº  122  | Expected result:  4  | Obtained result:  4  |   OK   | Accuracy:  99.18 %
# Nº  123  | Expected result:  7  | Obtained result:  7  |   OK   | Accuracy:  99.19 %
# Nº  124  | Expected result:  6  | Obtained result:  6  |   OK   | Accuracy:  99.19 %
# Nº  125  | Expected result:  7  | Obtained result:  7  |   OK   | Accuracy:  99.2 %
# Nº  126  | Expected result:  9  | Obtained result:  9  |   OK   | Accuracy:  99.21 %
# Nº  125  | Expected result:  7  | Obtained result:  7  |   OK   | Accuracy:  99.2 %
# Nº  126  | Expected result:  9  | Obtained result:  9  |   OK   | Accuracy:  99.21 %
# Nº  127  | Expected result:  0  | Obtained result:  0  |   OK   | Accuracy:  99.21 %
# Nº  128  | Expected result:  5  | Obtained result:  5  |   OK   | Accuracy:  99.22 %
# Nº  129  | Expected result:  8  | Obtained result:  8  |   OK   | Accuracy:  99.22 %
# Nº  127  | Expected result:  0  | Obtained result:  0  |   OK   | Accuracy:  99.21 %
# Nº  128  | Expected result:  5  | Obtained result:  5  |   OK   | Accuracy:  99.22 %
# Nº  129  | Expected result:  8  | Obtained result:  8  |   OK   | Accuracy:  99.22 %
# Nº  130  | Expected result:  5  | Obtained result:  5  |   OK   | Accuracy:  99
| Expected result:  5  | Obtained result:  5  |   OK   | Accuracy:  99.47 %
# Nº  188  | Expected result:  5  | Obtained result:  5  |   OK   | Accuracy:  99.47 %
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[40], line 5
#       3 for i in range(len(test_y)):
#       4     expectedResult = int(test_y[int(i)])
# ----> 5     result = knn.predict(test_x[int(i)].reshape(1, -1)).item()
#       6     outcome = "Fail"
#       7     if result == expectedResult:
#
# File c:\Anaconda\Lib\site-packages\sklearn\neighbors\_classification.py:271, in KNeighborsClassifier.predict(self, X)
#     268         return self.classes_[np.argmax(probabilities, axis=1)]
#     269     # In that case, we do not need the distances to perform
#     270     # the weighting so we do not compute them.
# --> 271     neigh_ind = self.kneighbors(X, return_distance=False)
#     272     neigh_dist = None
#     273 else:
#
# File c:\Anaconda\Lib\site-packages\sklearn\neighbors\_base.py:850, in KNeighborsMixin.kneighbors(self, X, n_neighbors, return_distance)
#     843 use_pairwise_distances_reductions = (
#     844     self._fit_method == "brute"
#     845     and ArgKmin.is_usable_for(
#     846         X if X is not None else self._fit_X, self._fit_X, self.effective_metric_
#     847     )
#     848 )
#     849 if use_pairwise_distances_reductions:
# --> 850     results = ArgKmin.compute(
#     851         X=X,
#     852         Y=self._fit_X,
#     853         k=n_neighbors,
#     854         metric=self.effective_metric_,
#     855         metric_kwargs=self.effective_metric_params_,
#     856         strategy="auto",
#     857         return_distance=return_distance,
#     858     )
#     860 elif (
#     861     self._fit_method == "brute" and self.metric == "precomputed" and issparse(X)
#     862 ):
#     863     results = _kneighbors_from_graph(
#     864         X, n_neighbors=n_neighbors, return_distance=return_distance
#     865     )
#
# File c:\Anaconda\Lib\site-packages\sklearn\metrics\_pairwise_distances_reduction\_dispatcher.py:278, in ArgKmin.compute(cls, X, Y, k, metric, chunk_size, metric_kwargs, strategy, return_distance)
#     197 """Compute the argkmin reduction.
#     198
#     199 Parameters
#    (...)
#     275 returns.
#     276 """
#     277 if X.dtype == Y.dtype == np.float64:
# --> 278     return ArgKmin64.compute(
#     279         X=X,
#     280         Y=Y,
#     281         k=k,
#     282         metric=metric,
#     283         chunk_size=chunk_size,
#     284         metric_kwargs=metric_kwargs,
#     285         strategy=strategy,
#     286         return_distance=return_distance,
#     287     )
#     289 if X.dtype == Y.dtype == np.float32:
#     290     return ArgKmin32.compute(
#     291         X=X,
#     292         Y=Y,
#    (...)
#     298         return_distance=return_distance,
#     299     )
#
# File sklearn\\metrics\\_pairwise_distances_reduction\\_argkmin.pyx:90, in sklearn.metrics._pairwise_distances_reduction._argkmin.ArgKmin64.compute()
#
# File c:\Anaconda\Lib\site-packages\sklearn\utils\fixes.py:94, in threadpool_limits(limits, user_api)
#      92     return controller.limit(limits=limits, user_api=user_api)
#      93 else:
# ---> 94     return threadpoolctl.threadpool_limits(limits=limits, user_api=user_api)
#
# File c:\Anaconda\Lib\site-packages\threadpoolctl.py:171, in threadpool_limits.__init__(self, limits, user_api)
#     167 def __init__(self, limits=None, user_api=None):
#     168     self._limits, self._user_api, self._prefixes = \
#     169         self._check_params(limits, user_api)
# --> 171     self._original_info = self._set_threadpool_limits()
#
# File c:\Anaconda\Lib\site-packages\threadpoolctl.py:268, in threadpool_limits._set_threadpool_limits(self)
#     265 if self._limits is None:
#     266     return None
# --> 268 modules = _ThreadpoolInfo(prefixes=self._prefixes,
#     269                           user_api=self._user_api)
#     270 for module in modules:
#     271     # self._limits is a dict {key: num_threads} where key is either
#     272     # a prefix or a user_api. If a module matches both, the limit
#     273     # corresponding to the prefix is chosed.
#     274     if module.prefix in self._limits:
#
# File c:\Anaconda\Lib\site-packages\threadpoolctl.py:340, in _ThreadpoolInfo.__init__(self, user_api, prefixes, modules)
#     337     self.user_api = [] if user_api is None else user_api
#     339     self.modules = []
# --> 340     self._load_modules()
#     341     self._warn_if_incompatible_openmp()
#     342 else:
#
# File c:\Anaconda\Lib\site-packages\threadpoolctl.py:373, in _ThreadpoolInfo._load_modules(self)
#     371     self._find_modules_with_dyld()
#     372 elif sys.platform == "win32":
# --> 373     self._find_modules_with_enum_process_module_ex()
#     374 else:
#     375     self._find_modules_with_dl_iterate_phdr()
#
# File c:\Anaconda\Lib\site-packages\threadpoolctl.py:478, in _ThreadpoolInfo._find_modules_with_enum_process_module_ex(self)
#     474 n_size = DWORD()
#     475 for h_module in h_modules:
#     476
#     477     # Get the path of the current module
# --> 478     if not ps_api.GetModuleFileNameExW(
#     479             h_process, h_module, ctypes.byref(buf),
#     480             ctypes.byref(n_size)):
#     481         raise OSError("GetModuleFileNameEx failed")
#     482     filepath = buf.value
#
# KeyboardInterrupt:

# %% [markdown]
# ## 10. Resultados finales
#
# Mostramos el resumen de tiempos y precisión.

# %%
# Mostrar resultados finales
print("-------------------------------")
print("Resultados")
print("-------------------------------")
print("Muestras de entrenamiento: ", muestras_entrenamiento)
print("Tiempo de entrenamiento: ", round(tiempo_entrenamiento, 2), " s")
print("Muestras de prueba: ", muestras_prueba)
print("Tiempo de prueba: ", round(tiempo_prueba, 2), " s")
print("Precisión en prueba: ", round((resultados_validos / muestras_prueba) * 100, 2), "%")
