# %% [markdown]
# # Cálculo de la matriz de correlación de Pearson
#
# Este notebook muestra cómo calcular y visualizar la matriz de correlación de Pearson usando el archivo `cleaned_dataset.csv` (una versión limpia del Pima Indian Dataset).

# %%
# Importar librerías necesarias
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Cargar el dataset
#
# Leemos el archivo `cleaned_dataset.csv` en un DataFrame de pandas.

# %%
# Cargar el dataset limpio
df = pd.read_csv('../../datasets/pima_indian_diabetes_dataset/cleaned_dataset.csv')
df.head()
# Out:
#    Pregnancies  Glucose  Blood Pressure  Skin Thickness  Insulin   BMI  \
# 0            2      108              62              32       56  25.2
# 1            0      137              68              14      148  24.8
# 2            1       89              66              23       94  28.1
# 3            0      139              62              17      210  22.1
# 4            4       99              76              15       51  23.2
#
#    Diabetes Pedigree Function  Age  Outcome
# 0                       0.128   21        0
# 1                       0.143   21        0
# 2                       0.167   21        0
# 3                       0.207   21        0
# 4                       0.223   21        0

# %% [markdown]
# ## Calcular la matriz de correlación de Pearson
#
# Utilizamos el método `.corr()` de pandas para obtener la matriz de correlación.

# %%
# Calcular la matriz de correlación de Pearson
correlation_matrix = df.corr(method='pearson')
correlation_matrix
# Out:
#                             Pregnancies   Glucose  Blood Pressure  \
# Pregnancies                    1.000000  0.198291        0.213355
# Glucose                        0.198291  1.000000        0.210027
# Blood Pressure                 0.213355  0.210027        1.000000
# Skin Thickness                 0.093209  0.198856        0.232571
# Insulin                        0.078984  0.581223        0.098512
# BMI                           -0.025347  0.209516        0.304403
# Diabetes Pedigree Function     0.007562  0.140180       -0.015971
# Age                            0.679608  0.343641        0.300039
# Outcome                        0.256566  0.515703        0.192673
#
#                             Skin Thickness   Insulin       BMI  \
# Pregnancies                       0.093209  0.078984 -0.025347
# Glucose                           0.198856  0.581223  0.209516
# Blood Pressure                    0.232571  0.098512  0.304403
# ...

# %% [markdown]
# ## Visualizar la matriz de correlación
#
# Usamos un heatmap de seaborn para visualizar la matriz de correlación.

# %%
# Visualizar la matriz de correlación con un heatmap azul-blanco-rojo
plt.figure(figsize=(10,8))
sns.heatmap(
    correlation_matrix, 
    annot=True, 
    cmap='bwr',  # Blue-White-Red
    center=0,
    fmt=".2f"
)
plt.title('Matriz de correlación de Pearson')
plt.show()
